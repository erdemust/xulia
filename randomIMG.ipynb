# %% [markdown]
# <a href="https://colab.research.google.com/github/erdemust/xulia/blob/master/randomIMG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# rast gele renkler

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
from pathlib import Path
import cv2 as cv
img = 255* np.ones((36,36,3), dtype = "uint8")
for i in range(36):
  for j in range(36):
    
    img[i,j,0]= np.random.randint(0,256)
    img[i,j,1]= np.random.randint(0,256)
    img[i,j,2]= np.random.randint(0,256)



plt.imshow(img)
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
from pathlib import Path
import cv2 as cv
img = 255* np.ones((36,36,3), dtype = "uint8")
for i in range(36):
  for j in range(36):
    
    img[i,j,0]= 128+ np.random.randint(0,128)
    img[i,j,1]= 128+ np.random.randint(0,128)
    img[i,j,2]= 128+ np.random.randint(0,128)


plt.imshow(img)
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
from pathlib import Path
import cv2 as cv
img = 255* np.ones((7,7,3), dtype = "uint8")
for i in range(4 ):
  for j in range(4):
    img[i,j,0]=(64*i)+j
    img[i,j,1]=(64*j)+j
    img[i,j,2]=(64*i)+j
#print(img)


plt.imshow(img)
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
from pathlib import Path
import cv2 as cv
img = 255* np.ones((17,17,3), dtype = "uint8")
for i in range(16 ):
  for j in range(16):
    img[i,j,0]=16*j
    img[i,j,1]=16*i
    img[i,j,2]=0
#print(img)


plt.imshow(img)
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
from pathlib import Path
import cv2 as cv
img = 255* np.ones((16,16,3), dtype = "uint8")
for i in range(16):
  for j in range(16):
    img[i,j,0]=(16*i)+np.random.randint(128)
    img[i,j,1]=(16*j)+np.random.randint(128)
    img[i,j,2]=(256)+np.random.randint(256)
#print(img)


plt.imshow(img)
plt.show()
